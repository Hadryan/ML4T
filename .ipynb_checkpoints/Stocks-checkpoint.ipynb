# %%
import pandas as pd

csv_data = pd.read_csv('./data/csv_data.csv', index_col=0)  
csv_data.head(10)
# Out:
#          time         code  next_close  close  pe_ratio  pb_ratio  pcf_ratio  \
# 0  2010-12-31  000002.XSHE        6.18   6.20 -0.353477 -0.353307   0.360895
# 1  2010-12-31  000006.XSHE        3.25   3.19  0.226630  0.226844  -0.220561
# 2  2010-12-31  000009.XSHE        7.77   7.34  0.138608  0.138669  -0.136737
# 3  2010-12-31  000012.XSHE       10.68  11.11 -0.016728 -0.015922   0.045756
# 4  2010-12-31  000021.XSHE        9.82  10.77  0.155642  0.155262  -0.157839
# 5  2010-12-31  000024.XSHE       10.02   9.96  0.075874  0.075997  -0.068320
# 6  2010-12-31  000028.XSHE       26.53  31.09  0.197032  0.198329  -0.191321
# 7  2010-12-31  000029.XSHE        4.62   4.66  0.231433  0.230854  -0.214374
# 8  2010-12-31  000031.XSHE        5.57   5.67  0.186061  0.185874  -0.184684
# 9  2010-12-31  000039.XSHE       17.55  15.68 -0.154972 -0.154857   0.156418
#
#    market_cap       PEG   roe_ttm  ...  sharpe_ratio_20  \
# 0    903.8063 -0.352715 -0.352921  ...         0.353005
# ...

# %%
## Target and Label
features = list(set(csv_data.columns) - set(['pct_change', 'close', 'target', 'time', 'code', 'next_close']))
labels = csv_data[features]
target = csv_data.target

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, r2_score
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFECV, SelectKBest, chi2, f_regression
from xgboost import XGBClassifier
from sklearn.linear_model import Lasso

## 训练数据和验证数据
X_train, X_test, y_train, y_test = train_test_split(labels, target, test_size=0.33)

# %% [markdown]
# ### Feature Selection

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

rfecv = RFECV(RandomForestClassifier(), cv=3, scoring='accuracy', n_jobs=4);
rfecv.fit(X_train, y_train)
print("Optimal number of features : %d" % rfecv.n_features_)

# %%
feature_be_selected = pd.DataFrame(index=labels.columns)
feature_be_selected['support'] = rfecv.support_
feature_be_selected['rank'] = rfecv.ranking_
feature_be_selected.rank.plot(style='bar')

# %%
selected_columns = feature_be_selected[feature_be_selected.support == True].index
labels = labels[selected_columns]
## 训练数据和验证数据
X_train, X_test, y_train, y_test = train_test_split(labels, target, test_size=0.33)

# %%
X_train = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train, columns=selected_columns)

abc = GridSearchCV(
    estimator=XGBClassifier(),
    param_grid={
        'n_estimators': (100, 110, 120, 130),
        'max_depth': (3, 4, 5, 6),
        'learning_rate': (0.1, 0.2, 0.3)
    }, 
    cv=4,
    n_jobs=4)

abc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-b03f2d494842> in <module>
#      15     n_jobs=4)
#      16
# ---> 17 abc.fit(X_train, y_train)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ...

# %%
## scaler only transform the test data without fit 
X_test = scaler.transform(X_test)
X_test = pd.DataFrame(X_test, columns=selected_columns)
y_pred = abc.predict(X_test)
print('分类报告: %s' % classification_report(y_test, y_pred))

# %%
abc.fit(labels, target)

def save_model(m_model, name):
    import pickle
    from six import BytesIO
    pkl_file = open(f'{name}.pkl', 'wb')
    pickle.dump(m_model, pkl_file, 0)
    pkl_file.close()
    
save_model(abc, 'svm')
